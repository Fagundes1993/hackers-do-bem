# %% [markdown]
# # Curso Hackers do Bem - Aula 1 - Entrada, Saída e Processamento

# %% [markdown]
# ## Comando print

# %%
print("Olá mundo!")
# Out:
# Olá mundo!

# %%
print("Um texto qualquer")
# Out:
# Um texto qualquer

# %% [markdown]
# ## Comando Input

# %%
input("Digite o seu nome: ")
# Out:
# Digite o seu nome: Matheus
# 'Matheus'

# %% [markdown]
# ##Variável

# %%
nome = input("Digite o seu nome:\n")
print(nome)
# Out:
# Digite o seu nome:
# Matheus
# Matheus
