# %% [markdown]
# # Curso Hackers do Bem - Aula 2 - Variável

# %% [markdown]
# ## Variável

# %%
nome = input("Digite o seu nome:\n")
print(nome)
# Out:
# Digite o seu nome:
# Matheus
# Matheus

# %%
frase = input("Digite uma frase: ")
print(frase)
# Out:
# Digite uma frase: Olá Mundo!
# Olá Mundo!

# %% [markdown]
# ## Tipos de variável

# %%
idade = 20
type(idade)
# Out:
# int

# %%
idade = "20"
type(idade)
# Out:
# str

# %%
altura = 1.87
type(altura)
# Out:
# float

# %% [markdown]
# ### Conversão de string para float

# %%
altura = float("1.87")
type(altura)
print(altura)
# Out:
# 1.87

# %% [markdown]
# ###Conversão de float para int

# %%
idade = int(20.8)
type(idade)
print(idade)
# Out:
# 20

# %% [markdown]
# ## Tipo Booleano

# %%
teste = True
type(teste)
# Out:
# bool
